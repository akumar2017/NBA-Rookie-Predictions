# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
use_cols = ['rpts','rrebs','rasts','rstls','rblks','rtos','rmin','rgamp','rgams','rfg%','rft%','r3fg%','rWS/48','rBPM','rPER','rTS%','rVORP']
df = pd.read_csv('dataset_preprocessedv3.csv', usecols = use_cols)

# %%
df
# Out:
#           rpts      rrebs     rasts     rstls     rblks      rtos  rmin  \
# 0     9.244444   8.711111  0.088889  0.622222  1.422222  1.066667   405
# 1    20.417143   4.011429  3.805714  1.491429  0.617143  2.777143   700
# 2    15.373494  12.674699  1.566265  1.204819  0.939759  2.698795  1494
# 3     9.464151   6.792453  1.494340  1.267925  0.407547  1.086792   795
# 4    14.765407   6.506473  1.771103  1.006732  0.316934  1.827033  1931
# ..         ...        ...       ...       ...       ...       ...   ...
# 190  16.796813   4.366534  4.239044  1.482072  0.207171  3.123506  2259
# 191  14.656827   4.250923  2.568266  1.062731  0.221402  2.346863   813
# 192  20.596879  11.757899  2.206319  0.794823  1.891131  2.507804  2627
# 193  16.301390   8.743233  1.079737  0.658376  2.264813  1.764448  1367
# 194   8.096774   6.500000  1.887097  1.096774  0.419355  1.532258  2232
#
#      rgamp  rgams      rfg%      rft%     r3fg%  rWS/48  rBPM  rPER   rTS%  \
# 0       39      4  0.661538  0.900000  0.000000   0.156  -2.9  12.1  0.705
# 1       56     16  0.518395  0.807692  0.409091   0.134   1.3  18.5  0.617
# 2       82     23  0.555556  0.546584  0.000000   0.147   0.7  17.7  0.564
# 3       71      1  0.396396  0.622642  0.000000   0.031  -4.1   8.5  0.426
# 4       77     31  0.446429  0.672414  0.369458   0.063  -2.1  13.0  0.529
# ..     ...    ...       ...       ...       ...     ...   ...   ...    ...
# 190     80     48  0.410042  0.736842  0.351351   0.001  -1.8  13.2  0.507
# 191     55      2  0.504132  0.750000  0.382979   0.119  -1.0  11.9  0.586
# 192     82     82  0.542064  0.810909  0.340909   0.151   2.8  22.5  0.590
# 193     60     30  0.498113  0.727273  0.214286   0.109  -2.3  15.4  0.531
# 194     78      8  0.422078  0.683761  0.275862   0.054  -0.6   8.4  0.489
#
#      rVORP
# 0     -0.1
# 1      0.6
# 2      1.0
# 3     -0.4
# 4     -0.1
# ..     ...
# 190    0.1
# 191    0.2
# 192    3.2
# 193   -0.1
# 194    0.8
#
# [195 rows x 17 columns]

# %%
sns.set(style="white")
corr = df.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=0.5, cbar_kws={"shrink": .5})
